# %%
pwd()
# Out:
# 'E:\\META\\ltrc'

# %%
import codecs
import glob
import regex as re
import pandas as pd
# for converting wx to utf notation
import wxconv
import numpy as np
from wxconv import WXC

# %%
# %cd E:\\META\\ltrc
# Out:
# E:\META\ltrc

# %%
def getLines(file,splitby):
    with codecs.open(file, 'r', encoding="utf-8") as filer:
                    data = filer.read()
                    data = re.sub('\t+', '\t', data)
    lines = data.split(splitby)
    return lines

# %%
def get_sentence(row):
    ret=re.findall('"(.+?)"', row['gloss'])
    return ret
def get_gloss(row):
    ret = []
    split = row['gloss'].split(';')
    for i in split:
        if '"' not in i:
            ret.append(i)
        else:
            break
    return ret

# %%
#converting hin-eng linked data to a dataframe
with codecs.open('English_Hindi_Linked_Synsets', 'r', encoding="utf-8") as filer:
                    data = filer.read()
                    data = re.sub('\t+', '\t', data)
with codecs.open('English_Hindi_Linked_Synsets_m.txt', 'w', encoding="utf-8") as filew:
    filew.write(data)
linked_df = pd.read_csv('English_Hindi_Linked_Synsets_m.txt', sep='\t',na_filter = False)
linked_df['synset_words'] = linked_df['synset_words'].str.split(', ')
linked_df['hindi_synset_words'] = linked_df['hindi_synset_words']+','
linked_df['eng_ex'] = linked_df.apply(lambda row: get_sentence(row), axis=1)
linked_df['gloss'] = linked_df.apply(lambda row: get_gloss(row), axis=1)
mask_no_engex = linked_df.eng_ex.apply(lambda x: len(x)==0)
print("Total no. of instances : " + str(len(linked_df)))
print("No. of instances having no english examples: " + str(len(linked_df[mask_no_engex])))
#linked_df.assign(eng_ex = get_sentence(linked_df['gloss'].astype("string"))
linked_df[10:25]
# Out:
# Total no. of instances : 17787
# No. of instances having no english examples: 10315
#     SNo  synset_id   category  \
# 10   11   10069427       NOUN
# 11   12    1020936       NOUN
# 12   13    7090019       NOUN
# 13   14   10085970       NOUN
# 14   15    4058096       NOUN
# 15   16    2119971  ADJECTIVE
# 16   17     150505  ADJECTIVE
# 17   18   10420031       NOUN
# 18   19    1380267  ADJECTIVE
# 19   20    1380267  ADJECTIVE
# 20   21    4715075       NOUN
# 21   22    3650084       NOUN
# 22   23    9930876       NOUN
# 23   24   11449419       NOUN
# 24   25    4911894       NOUN
#
#                                          synset_words  \
# 10                  [executioner, public_executioner]
# 11                                        [imitation]
# 12                              [verbiage, verbalism]
# 13                             [fiancee, bride-to-be]
# 14                                     [reading_room]
# 15                       [thoughtful, serious-minded]
# 16  [eloquent, facile, fluent, silver, silver-tong...
# 17     [petitioner, suppliant, supplicant, requester]
# 18                                           [aerial]
# 19                                           [aerial]
# 20                                            [irony]
# 21                                         [laxative]
# 22                     [clown, buffoon, merry_andrew]
# 23        [electrical_power, electric_power, wattage]
# 24                                      [stateliness]
#
#                                    hindi_synset_words hindi_synset_id  \
# 10                                   जल्लाद,वधिक,वधक,           10016
# 11  अनुकरण,अनुसरण,अनुगमन,नक़ल,नकल,अनुकार,अनुसार,अन...            1002
# 12              शब्दजाल,शब्दाडंबर,शब्दाडम्बर,वाक्जाल,           10022
# 13                                         वाग्दत्ता,           10024
# 14                                           वाचनालय,           10025
# 15  विचारशील,विचारवान,दीर्घदर्शी,विचारवान्,बुद्धिज...           10026
# 16                                           वाक्पटु,           10030
# 17  वादी,फरियादी,मुद्दई,अभियोक्ता,अभियोगकर्ता,अभिय...           10032
# 18                                            वायव्य,           10033
# 19                                            वायव्य,           10033
# 20                                  विडंबना,विडम्बना,           10039
# 21                           विरेचन,रेचन,जुलाब,रेच्य,           10041
# 22                                            विदूषक,           10042
# 23                                     विद्युत्शक्ति,           10043
# 24                 एकान्तर,एकांतर,एकान्तरिक,एकांतरिक,           10044
#
#    hindi_category                                              gloss  \
# 10           noun  [an official who inflicts capital punishment i...
# 11           noun  [copying (or trying to copy) the actions of so...
# 12           noun                           [overabundance of words]
# 13           noun             [a woman who is engaged to be married]
# 14           noun                     [a room set aside for reading]
# 15      adjective    [acting with or showing thought and good sense]
# 16      adjective  [expressing yourself readily, clearly, effecti...
# 17           noun                 [one praying humbly for something]
# 18      adjective                                   [growing in air]
# 19      adjective  [in or belonging to the air or operating (for ...
# 20           noun  [incongruity between what might be expected an...
# 21           noun                                 [a mild cathartic]
# 22           noun  [a person who amuses others by ridiculous beha...
# 23           noun               [the product of voltage and current]
# 24      adjective            [a elaborate manner of doing something]
#
#                                                eng_ex
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                             [a sensible young man]
# 16  [able to dazzle with his facile tongue, silver...
# 17                       [a suppliant for her favors]
# 18                   [aerial roots of a philodendron]
# 19  [aerial particles, small aerial creatures such...
# 20  [the irony of Ireland' s copying the nation sh...
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24         [she served coffee with great stateliness]

# %%
# converting hindi synset data to a dataframe
d = {'ID':[],'CAT':[],'CONCEPT':[],'EXAMPLE':[],'SYNSET-HINDI':[]}
for line in getLines('hindi.syns','\n\n'):
    internal_lines = line.split('\n')
    #print(internal_lines)
    if len(internal_lines)>0:
        
        d['ID'].append(internal_lines[0].split('::')[1].strip())
        d['CAT'].append(internal_lines[1].split('::')[1].strip())
        d['CONCEPT'].append(internal_lines[2].split('::')[1].strip())
        d['EXAMPLE'].append(internal_lines[3].split('::')[1].strip())
        d['SYNSET-HINDI'].append(internal_lines[4].split('::')[1].strip())

hn_syns_df = pd.DataFrame.from_dict(d)
print(len(hn_syns_df))
hn_syns_df[:10]
# Out:
# 38759
#    ID        CAT                                            CONCEPT  \
# 0   1  ADJECTIVE                               जिसने जन्म न लिया हो
# 1   2  ADJECTIVE                                        जो शुभ न हो
# 2   3  ADJECTIVE                               जो प्रविष्ट न हुआ हो
# 3   4       NOUN                    वह स्थान जो पवित्र माना जाता हो
# 4   5       NOUN  वह मंदिर जिसमें भगवान शिव की मूर्ति स्थापित की...
# 5   6       NOUN                            वह स्थान जो पवित्र न हो
# 6   7  ADJECTIVE                                      जो आया हुआ हो
# 7   8  ADJECTIVE               जो पैदा हुआ हो या जिसने जन्म लिया हो
# 8   9       NOUN                            ऐसा कार्य जो नीतिपरक हो
# 9  10  ADJECTIVE                 जिसकी उत्पत्ति हुई हो या जो उगा हो
#
#                                              EXAMPLE  \
# 0  "देवकी के अजन्मे बालकों के विषय में भविष्यवाणी...
# 1  "बिल्ली के द्वारा रास्ता काटा जाना अशुभ माना ज...
# 2  "अप्रविष्ट अतिथियों को शीघ्र ही भीतर प्रवेश कर...
# 3         "हिंदुओं के लिए काशी एक पवित्र स्थान है ।"
# 4           "वह प्रत्येक सोमवार को शिवालय जाता है ।"
# 5  "धार्मिक मान्यता है कि भूत-प्रेत अपवित्र स्थान...
# 6                   "आगत व्यक्तियों का स्वागत करो ।"
# 7           "जन्मे प्राणियों की मृत्यु निश्चित है ।"
# 8  "नैतिक कार्यों के द्वारा ही हम समाज का उत्थान ...
# 9  "भारत में उत्पन्न चाय अधिक मात्रा में विदेशों ...
#
#                                         SYNSET-HINDI
# 0  अजन्मा:अजात:अनुत्पन्न:अनुद्भूत:अप्रादुर्भूत:अज...
# 1  अशुभ:अमांगलिक:अमाङ्गलिक:मनहूस:अमंगल:अमङ्गल:अक्...
# 2                                          अप्रविष्ट
# 3  पवित्र_स्थान:चैत्य_स्थान:पुण्य_भूमि:पुण्य-स्थल...
# 4  शिवालय:शिव_मंदिर:शिव_मन्दिर:शिवाला:सिवाला:सौधा...
# 5              अपवित्र_स्थान:अपुण्यभूमि:अपवित्रस्थली
# 6                                          आगत:समागत
# 7  जन्मा:उत्पन्न:जन्मा_हुआ:जात:संजात:जनित:प्रसूत:...
# 8  नैतिक_कार्य:सत्कर्म:सुकर्म:अच्छा_काम:सत्कार्य:...
# 9         उत्पन्न:पैदा_हुआ:पैदा:उपजा:उपजा_हुआ:उतपन्न

# %%
# converting mrs file into a dataframe
d ={'conc_label_wx':[],'conc_label_utf':[],'conc_in_eng':[],'mrs_conc':[]}
con = WXC(order='wx2utf', lang='hin')
for line in getLines('H_concept-to-mrs-rels.dat','\n'):
    internal_lines = line.split('\t')
    if len(internal_lines)>=4:
        d['conc_label_wx'].append(internal_lines[1])
        d['conc_label_utf'].append(con.convert(internal_lines[1]))
        d['conc_in_eng'].append(internal_lines[2])
        d['mrs_conc'].append(internal_lines[3])
    else:
        print(internal_lines[2])
        d['conc_label_wx'].append(internal_lines[1])
        d['conc_label_utf'].append(con.convert(internal_lines[1]))
        if len(internal_lines[2])>20:
            d['conc_in_eng'].append(internal_lines[2].split(' ')[0])
            d['mrs_conc'].append(internal_lines[2].split(' ')[1])
        else:
            d['conc_in_eng'].append(internal_lines[2][0:7])
            d['mrs_conc'].append(internal_lines[2][8:])
mrs_df = pd.DataFrame.from_dict(d)
print( "No. of instances in mrs file : "+ str(len(mrs_df)))
mrs_df[:10]
# Out:
# foundation+stone_1 _foundation_n_1+_stone_n_1)
# dutch_1_dutch_a_1_1)
# shrug_3_shrug_n_1_1)
# No. of instances in mrs file : 54329
#   conc_label_wx conc_label_utf   conc_in_eng                  mrs_conc
# 0           A_1            आ_1        come_1                _come_v_1)
# 1         Aba_1           आब_1      lustre_1     _lustre/NN_u_unknown)
# 2         ABA_1          आभा_1      lustre_2     _lustre/NN_u_unknown)
# 3         aba_1           अब_1         now_3           def_implicit_q)
# 4         aba_1           अब_1         now_3                loc_nonsp)
# 5         aba_1           अब_1         now_3                 _now_a_1)
# 6         aba_1           अब_1         now_3                   time_n)
# 7         Aba_2           आब_2  brilliance_1          _brilliance_n_1)
# 8         ABA_2          आभा_2   splendour_1  _splendour/NN_u_unknown)
# 9         ABA_3          आभा_3        tint_1               _tint_n_of)

# %%
def get_fin_df(row,d,ign):
    conc_label_hn = row['conc_label_utf']
    conc_eng = row['conc_in_eng']
    hn_label = conc_label_hn.split('_')[0]+','
    eng_label = conc_eng.split('_')[0]
    # checking ig the hindi label is present in the hindi synset words list
    mask = linked_df.hindi_synset_words.apply(lambda x: hn_label in x)
    # checking if the eng label is present in the hindi sysnet word list
    mask1 = linked_df.synset_words.apply(lambda x: eng_label in x)
    # taking intersection of both the conditions
    cross = linked_df[mask & mask1]
    cross = cross.reset_index()  
    if cross.empty == False:
        for index, row in cross.iterrows():
            if (row['synset_id'] not in d['eng_id']) and (row['hindi_synset_id'] not in d['hin_id']):
                d['hin'].append(conc_label_hn)
                d['eng'].append(conc_eng)
                d['eng_id'].append(row['synset_id'])
                d['hin_id'].append(row['hindi_synset_id'])
                d['eng_gloss'].append(row['gloss'])
                d['eng_ex'].append(row['eng_ex'])
                if len(hn_syns_df[hn_syns_df['ID']==row['hindi_synset_id']]) != 0:
                    # getting hindi example and concept from the hindi synset dataframe
                    d['hin_ex'].append(hn_syns_df[hn_syns_df['ID']==row['hindi_synset_id']].EXAMPLE.item())
                    d['hin_gloss'].append(hn_syns_df[hn_syns_df['ID']==row['hindi_synset_id']].CONCEPT.item())
                else:
                    # if the hindi synset id is not found in hindi synset df. then adding empty strings
                    d['hin_ex'].append("")
                    d['hin_gloss'].append("")
    else:
        # adding hindi-word and eng_concept pairs not found to the ign dict
        ign['hindi_ig'].append(conc_label_hn)
        ign['eng_conc_ig'].append(conc_eng)

# %%
d = {'hin' : [],'eng' : [], 'hin_id':[],'eng_id':[], 'hin_gloss':[],'eng_gloss':[], 'hin_ex':[],'eng_ex':[]}
ign = {'hindi_ig' :[], 'eng_conc_ig':[]}
mrs_df.apply(lambda row: get_fin_df(row,d,ign), axis=1)
# final dataframe depending on the hindi label and eng conc from mrs
fin_df = pd.DataFrame.from_dict(d)
#ignored pairs which were not found in eng-hindi linked df
ign_df = pd.DataFrame.from_dict(ign)

# %%
mask_no_engex = fin_df.eng_ex.apply(lambda x: len(x)==0)
mask_no_hin_id = fin_df.hin_ex.apply(lambda x: x=="")
print("No. of total instances: " + str(len(fin_df)))
print("No. of instances having no corresponding hindi ids :" + str(len(fin_df[mask_no_hin_id])))
print("No. of instances having no english examples :" + str(len(fin_df[mask_no_engex])))
print("No. of ignored pairs from the MRS: " + str(len(ign_df)))
#fin_df[mask_no_hin_id]
fin_df[300:310]
# Out:
# No. of total instances: 5870
# No. of instances having no corresponding hindi ids :135
# No. of instances having no english examples :3336
# No. of ignored pairs from the MRS: 42256
#                hin          eng hin_id    eng_id  \
# 300       अल्पता_1  smallness_4   9947   5106633
# 301    अल्टीमेटम_1  ultimatum_1  24553   7191696
# 302          आलू_1     potato_1  14171  12897493
# 303          आलू_1     potato_1   3568   7710616
# 304  आलू-बुख़ारा_1       plum_2  20072  12638218
# 305  आलू-बुख़ारा_1       plum_2  20073   7751451
# 306           आम_1      mango_1   3462   7764155
# 307           आम_1      mango_1   3463  12761284
# 308         अमला_1      staff_1  28390   8439955
# 309          अमल_4  addiction_1   2855  14062725
#
#                                              hin_gloss  \
# 300                  लघु या छोटे होने की अवस्था या भाव
# 301  किसी काम को निर्धारित समयावधि में पूर्ण किए जा...
# 302                एक पौधा जिसके कंद की तरकारी बनती है
# 303  एक प्रकार का कन्द जो सब्जी के रूप में खाया जात...
# 304             एक पेड़ जिसके खटमिट्ठे फल खाए जाते हैं
# 305  एक पेड़ से प्राप्त गहरे लाल रंग का गोल तथा खटम...
# 306                      एक फल जो खाया या चूसा जाता है
# 307  गर्म देशों में पाया जाने वाला एक बड़ा, सदाबहार...
# 308  वह कर्मचारी वर्ग जो अपने अधिकारी आदि को निर्धा...
# 309                                           बुरी आदत
#
#                                              eng_gloss  \
# 300   [the property of having a relatively small size]
# 301                        [a final peremptory demand]
# 302  [annual native to South America having undergr...
# 303  [an edible tuber native to South America,  a s...
# 304  [any of several trees producing edible oval fr...
# 305  [any of numerous varieties of small to medium-...
# 306  [large oval tropical fruit having smooth skin,...
# 307  [large evergreen tropical tree cultivated for ...
# 308  [personnel who assist their superior in carryi...
# 309  [being abnormally tolerant to and dependent on...
#
#                                                 hin_ex  \
# 300            "किसी को लघुता महसूस नहीं करनी चाहिए ।"
# 301  "मैं आज आपको अल्टीमेटम देने आया हूँ कि कल तक म...
# 302          "किसान खेत में आलू की सिंचाई कर रहा है ।"
# 303  "आलू बारहों महीने बाजार में उपलब्ध रहने वाली स...
# 304  "आलूबुखारा के फल थोड़े छोटे और गहरे लाल रंग के...
# 305                       "शीला आलूबुखारा खा रही है ।"
# 306  "तोता पेड़ पर बैठकर आम खा रहा है । / शास्त्रों...
# 307  "आम की लकड़ी का उपयोग साज-सज्जा की वस्तुएँ बना...
# 308          "इस विद्यालय का स्टाफ बहुत ही अच्छा है ।"
# 309                                 "कुव्यसन से बचो ।"
#
#                                                 eng_ex
# 300                                                 []
# 301                                                 []
# 302                                                 []
# 303                                                 []
# 304                                                 []
# 305                                                 []
# 306                                                 []
# 307                                                 []
# 308  [the hospital has an excellent nursing staff, ...
# 309                                                 []

# %%
ign_df[:20]
# Out:
#       hindi_ig     eng_conc_ig
# 0          आ_1          come_1
# 1         आब_1        lustre_1
# 2         आब_2    brilliance_1
# 3        आभा_2     splendour_1
# 4        आभा_3          tint_1
# 5        आभा_4         tinge_1
# 6      अभागा_2      accursed_1
# 7      अभागा_3       unlucky_1
# 8     अभागिन_1      accursed_2
# 9     आबकारी_1        excise_1
# 10  आभामण्डल_1          halo_4
# 11      अभंग_1      unbroken_5
# 12      अभंग_2    unimpaired_4
# 13    आबपाशी_2      watering_1
# 14    आबपाशी_2      watering_1
# 15      आभार_1    obligation_2
# 16      आभार_3  indebtedness_1
# 17      अभरक_1          mica_2
# 18      आभरण_1      ornament_3
# 19      आभरण_2    decoration_1

# %%
fin_df.to_csv('final_linked_set.csv', sep ='\t')
